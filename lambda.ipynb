# %%
add = lambda x,y:x*y
print(add(10,20))
# Out:
# 200

# %%
odd_even =lambda x: "even" if x%2 == 0 else "not even"
a=int(input("enter number"))
print(odd_even(a))
# Out:
# enter number 5
# not even

# %%
# wap a prog to check eligibiligty of check vote 
age = int(input("Enter your age: "))

check_vote = lambda age: "Eligible for voting" if age >= 18 else "Not eligible for voting"
print(check_vote(age))
# Out:
# Enter your age:  15
# Not eligible for voting

# %%
add = lambda x,y:[x*y,x+y,x /y, x-y]
print(add(10,20))
# Out:
# [200, 30, 0.5, -10]

# %%
length = lambda text: len(text)

print(length("Python"))
# Out:
# 6

# %%
# Filter Function 
def check_marks(marks):
    return marks>=55
marks = [20,45, 67, 89]
res=filter(check_marks, marks)
print(list(res))
# Out:
# [67, 89]

# %%
marks = [20,45, 67, 89]
print(list(filter(lambda x: x>=55 , marks)))
# Out:
# [67, 89]
