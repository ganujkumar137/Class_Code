# %%
for i in range(1,10):
    if i % 2 == 0:
        print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
import pymysql

conn = pymysql.connect(
    host="localhost",
    user="root",
    password="root",
    database="student"
)

print("Success")
# Out:
# Success

# %%
name = "PYTHON"
for i in range(len(name)):
  print((name[i]) , name ,i)
# Out:
# P PYTHON 0
# Y PYTHON 1
# T PYTHON 2
# H PYTHON 3
# O PYTHON 4
# N PYTHON 5

# %%
# #While loop condition based loop
# Initialization
# condition
# decrement/ increment
i=1
while i<=10
